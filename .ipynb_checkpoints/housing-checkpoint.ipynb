# %%
import numpy as np
import pandas as pd
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv('housing.csv',encoding="")
data.head()
# Out:
#    Unnamed: 0  learner_id program_code variation_code message_in  \
# 0           1           8          HFH            HFH        hfh
# 1           2           8          HFH            HFH          a
# 2           3           8           PL             PL          1
# 3           4           8           PL             PL          a
# 4           5           8           PL             PL          a
#
#                                          message_out           created_at  \
# 0  Housing is a basic need but not everyone can a...  2017-12-20 11:55:19
# 1  All SMSs are FREE. Reply with a number to lear...  2017-12-20 11:56:19
# 2  (1/9) Did you know that people who have been s...  2017-12-20 11:58:05
# 3  (2/9) To create a home plan, you need to follo...  2017-12-20 11:59:00
# 4  (3/9) Step 1: Anne decided where and what she ...  2017-12-20 12:00:07
#
#   user_response
# 0             a
# 1             1
# 2             a
# 3             a
# 4   ACCESS|DIGI

# %%
# How many learners were in the housing trainings project?
print(data.learner_id.nunique())
# Out:
# 15641

# %%
# Which were the 3 most popular trainings? (Trainings with the most learners)
print(data.program_code.value_counts())
# Out:
# PLB    123652
# HFS     78505
# SF      55654
# HFH     55275
# PL      53678
# SM      31622
# MW      24482
# Name: program_code, dtype: int64

# %%
data.describe(include='all')
# Out:
#            Unnamed: 0     learner_id program_code variation_code message_in  \
# count   422868.000000  422868.000000       422868         422868     421050
# unique            NaN            NaN            7             13       7756
# top               NaN            NaN          PLB            PLB          A
# freq              NaN            NaN       123652         120338     206272
# mean    211434.500000  331117.453078          NaN            NaN        NaN
# std     122071.621153  242367.504512          NaN            NaN        NaN
# min          1.000000       8.000000          NaN            NaN        NaN
# 25%     105717.750000   91560.000000          NaN            NaN        NaN
# 50%     211434.500000  270121.000000          NaN            NaN        NaN
# 75%     317151.250000  577151.000000          NaN            NaN        NaN
# max     422868.000000  781388.000000          NaN            NaN        NaN
#
#                                               message_out  \
# count                                              422722
# unique                                               1918
# top     All SMSs are FREE. Reply with a number to lear...
# freq                                                18693
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                  created_at user_response
# count                422868        409270
# unique               267973          7952
# top     2018-02-14 19:08:06             A
# freq                     26        205878
# mean                    NaN           NaN
# std                     NaN           NaN
# min                     NaN           NaN
# 25%                     NaN           NaN
# 50%                     NaN           NaN
# 75%                     NaN           NaN
# max                     NaN           NaN

# %%
# Which learner had the most interactions and how many interactions did they have?
data.learner_id.value_counts()
# Out:
# 648424    1172
# 13402      977
# 684685     704
# 281194     600
# 117080     537
# 64760      455
# 251815     440
# 203006     439
# 3357       400
# 197258     397
# 623036     396
# 28730      385
# 619004     381
# 279491     374
# 313375     374
# 248243     347
# 69041      338
# 6936       336
# 37747      321
# 600862     321
# 18562      320
# 89205      317
# 315392     315
# 114731     314
# 338184     308
# 595226     305
# 398916     303
# 656576     300
# 209603     299
# 169073     289
#           ...
# 148818       1
# 685223       1
# 236084       1
# 588248       1
# 682717       1
# 643453       1
# 708637       1
# 709415       1
# 197754       1
# 30408        1
# 89432        1
# 696190       1
# 682174       1
# 402021       1
# 137648       1
# 232450       1
# 635372       1
# 401804       1
# 150586       1
# 697435       1
# 685448       1
# 212244       1
# 559193       1
# 681354       1
# 8268         1
# 683403       1
# 208674       1
# 681483       1
# 178297       1
# 208557       1
# Name: learner_id, Length: 15641, dtype: int64

# %%
# How many learners had more than 100 interactions (>100) ?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-22a3a891828d> in <module>()
#       1 # How many learners had more than 100 interactions (>100) ?
# ----> 2 for atr, val in data.learner_id.value_counts():
#       3     print(atr, val)
#
# TypeError: 'int' object is not iterable
